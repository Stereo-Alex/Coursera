# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import datetime


# %matplotlib notebook

# %%
# millions of dollars not seasonally adjusted 
# https://fred.stlouisfed.org/series/MINGSP
df = pd.read_csv("MINGSP.csv")

# %%
#total gdp millions of dollars 
df1 = pd.read_csv("USNGSP.csv")

# %%
df.DATE = pd.to_datetime(df["DATE"])

# %%
df.DATE = pd.DatetimeIndex(df["DATE"]).year

# %%
df1.DATE = pd.to_datetime(df1["DATE"])

# %%
df1.DATE = pd.DatetimeIndex(df1["DATE"]).year

# %%
df1
# Out:
#     DATE      USNGSP
# 0   1997   8577552.0
# 1   1998   9062817.0
# 2   1999   9630663.0
# 3   2000  10252347.0
# 4   2001  10581822.0
# 5   2002  10936418.0
# 6   2003  11458246.0
# 7   2004  12213730.0
# 8   2005  13036637.0
# 9   2006  13814609.0
# 10  2007  14451860.0
# 11  2008  14712845.0
# 12  2009  14448932.0
# 13  2010  14992052.0
# 14  2011  15542582.0
# 15  2012  16197007.0
# 16  2013  16784851.0
# 17  2014  17527258.0
# 18  2015  18238301.0
# 19  2016  18745075.0
# 20  2017  19542980.0
# 21  2018  20611861.0
# 22  2019  21433226.0
# 23  2020  20936558.0

# %%
list_1 = []
base = df.MINGSP[0]

for i in df.MINGSP:
    change = ((i*100)/base)-100
    list_1.append(change)

# %%
df["Change"] = list_1

# %%
df
# Out:
#     DATE    MINGSP     Change
# 0   1997  299692.9   0.000000
# 1   1998  312667.6   4.329332
# 2   1999  337834.5  12.726895
# 3   2000  351641.3  17.333877
# 4   2001  348642.7  16.333320
# 5   2002  362311.0  20.894089
# 6   2003  372965.9  24.449361
# 7   2004  381443.4  27.278090
# 8   2005  394141.2  31.515028
# 9   2006  395685.3  32.030255
# 10  2007  403717.4  34.710365
# 11  2008  385990.3  28.795277
# 12  2009  365552.7  21.975763
# 13  2010  386629.8  29.008662
# 14  2011  401069.1  33.826694
# 15  2012  418742.3  39.723797
# 16  2013  433755.8  44.733425
# 17  2014  448572.1  49.677253
# 18  2015  473149.5  57.878115
# 19  2016  488962.6  63.154549
# 20  2017  501914.9  67.476407
# 21  2018  521803.4  74.112700
# 22  2019  536888.3  79.146153
# 23  2020  515928.3  72.152327

# %%
list_2 = []
base = df1.USNGSP[0]

for i in df1.USNGSP:
    change = ((i*100)/base)-100
    list_2.append(change)

# %%
dates = []

for i in df1.DATE:
    dates.append(i)

# %%
df1["Change"] = list_2

# %%
df1
# Out:
#     DATE      USNGSP      Change
# 0   1997   8577552.0    0.000000
# 1   1998   9062817.0    5.657383
# 2   1999   9630663.0   12.277524
# 3   2000  10252347.0   19.525326
# 4   2001  10581822.0   23.366457
# 5   2002  10936418.0   27.500457
# 6   2003  11458246.0   33.584104
# 7   2004  12213730.0   42.391792
# 8   2005  13036637.0   51.985520
# 9   2006  13814609.0   61.055380
# 10  2007  14451860.0   68.484668
# 11  2008  14712845.0   71.527319
# 12  2009  14448932.0   68.450532
# 13  2010  14992052.0   74.782409
# 14  2011  15542582.0   81.200674
# 15  2012  16197007.0   88.830181
# 16  2013  16784851.0   95.683465
# 17  2014  17527258.0  104.338697
# 18  2015  18238301.0  112.628277
# 19  2016  18745075.0  118.536419
# 20  2017  19542980.0  127.838665
# 21  2018  20611861.0  140.300041
# 22  2019  21433226.0  149.875792
# 23  2020  20936558.0  144.085469

# %%
df
# Out:
#     DATE    MINGSP     Change
# 0   1997  299692.9   0.000000
# 1   1998  312667.6   4.329332
# 2   1999  337834.5  12.726895
# 3   2000  351641.3  17.333877
# 4   2001  348642.7  16.333320
# 5   2002  362311.0  20.894089
# 6   2003  372965.9  24.449361
# 7   2004  381443.4  27.278090
# 8   2005  394141.2  31.515028
# 9   2006  395685.3  32.030255
# 10  2007  403717.4  34.710365
# 11  2008  385990.3  28.795277
# 12  2009  365552.7  21.975763
# 13  2010  386629.8  29.008662
# 14  2011  401069.1  33.826694
# 15  2012  418742.3  39.723797
# 16  2013  433755.8  44.733425
# 17  2014  448572.1  49.677253
# 18  2015  473149.5  57.878115
# 19  2016  488962.6  63.154549
# 20  2017  501914.9  67.476407
# 21  2018  521803.4  74.112700
# 22  2019  536888.3  79.146153
# 23  2020  515928.3  72.152327

# %%
df["Dates"] = dates

# %%
from matplotlib.pyplot import figure

figure(figsize=(12, 6), dpi=80)


plt.plot(df.Change, '-o', label= 'Michigans GDP progression', color='xkcd:off yellow')
plt.plot(df1.Change, '-o', label='U.S. GDP progression')

plt.xlabel('Years', fontsize='x-large')
plt.ylabel('% Change with base year 1997', fontsize='x-large')
plt.title("Michigan's  enconomic growth compared to overall U.S. economic growth", fontsize='x-large')

plt.xticks( range(0,24), dates)

plt.xticks(rotation=45)
plt.box(False)


plt.tick_params(axis=u'both', which=u'both',length=0)





plt.legend(loc='best', frameon = True, fontsize = 'medium')

plt.text(12,29,'21.97%',bbox={'facecolor':'white','alpha':1,'edgecolor':'black','pad':1},
          ha='center', va='center') 

plt.text(12,75,'68.45%',bbox={'facecolor':'white','alpha':1,'edgecolor':'black','pad':1},
          ha='center', va='center') 

plt.text(22,155,'144.1%',bbox={'facecolor':'white','alpha':1,'edgecolor':'black','pad':1},
          ha='center', va='center') 
plt.text(22,85,'79.15%',bbox={'facecolor':'white','alpha':1,'edgecolor':'black','pad':1},
          ha='center', va='center') 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="960">
